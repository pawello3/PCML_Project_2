# %%
# %matplotlib inline
import numpy as np
import scipy
import scipy.io
import scipy.sparse as sp
import pandas as pd
import matplotlib.pyplot as plt
import datetime
# %load_ext autoreload
# %autoreload 2
from helpers import *
from numba import jit
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path_dataset = "data_train.csv"
ratings0 = load_data(path_dataset)
print('Shape of ratings matrix:',ratings.shape)
# Out:
# number of items: 10000, number of users: 1000
# Shape of ratings matrix: (100, 100)

# %%
from plots import plot_raw_data

num_items_per_user, num_users_per_item = plot_raw_data(ratings)

print("min # of items per user = {}, min # of users per item = {}.".format(
        min(num_items_per_user), min(num_users_per_item)))
# Out:
# min # of items per user = 0, min # of users per item = 0.

# %%
# Let's first play with a submatrix
ratings = ratings0[:100,:100]
print('No of non-zero elements in ratings submatrix:',len(ratings.nonzero()[0]))
# Out:
# No of non-zero elements in ratings submatrix: 1213

# %%
ratings = ratings0

# %%
def init_MF_random(train, num_features):
    """init the parameter for matrix factorization."""
    
    #     to be returned:
    #     user_features: shape = num_features, num_user
    #     item_features: shape = num_features, num_item
    
    
    item_features = np.random.random((train.shape[0],num_features))  # W matrix initialization
    user_features = np.random.random((train.shape[1],num_features)) # Z matrix initialization
    
    return user_features, item_features

# %%
def init_MF(train, num_features):
    """init the parameter for matrix factorization."""
    
    #     to be returned:
    #     user_features: shape = num_features, num_user
    #     item_features: shape = num_features, num_item
    
    train_svd = np.zeros(train.shape)
    for i in range(train.shape[0]):
        for j in range(train.shape[1]):
            train_svd[i,j] = train[i,j]
    
    U, s, V = np.linalg.svd(train_svd, full_matrices=False)
    
    S = np.diag(s)

    U_1 = U[:,0:num_features]
    S_1 = S[0:num_features, 0:num_features]
    V_1 = V[0:num_features, :]
    
    item_features = U_1 # W matrix of the decomposition
    user_features = (S_1.dot(V_1) ).T # Z matrix of the decomposition
    
    
    #raise NotImplementedError
    
    return user_features, item_features

# %%
# define parameters
gamma = 0.000020
num_features = 50   # K in the lecture notes
lambda_user = 0.0
lambda_item = 0.0
num_epochs = 50     # number of full passes through the train set
errors = [0]

# set seed
np.random.seed(988)

train = ratings

# init matrix
user_features, item_features = init_MF_random(train, num_features)

# find the non-zero ratings indices 
nz_row, nz_col = train.nonzero()
nz_train = list(zip(nz_row, nz_col))

# %%
@jit
def sum2d(arr):
    M, N = arr.shape
    result = 0.0
    for i in range(M):
        for j in range(N):
            result += arr[i,j]
    return result

# %%
real_train_label = np.zeros(len(nz_train))
prediction_train = np.zeros(len(nz_train))
rmse_train = np.zeros(num_epochs)

for it in range(num_epochs): 
    
    print('Iteration sankhya',it,'haazir hoooooo!!!')
    # shuffle the training rating indices
    np.random.shuffle(nz_train)

    # decrease step size
    # gamma /= 1.2
    count = 0
    mat_pred = np.dot(item_features,user_features.T)
    begin = datetime.datetime.now()
    print('beginning step 1')
    count = 0
    for d,n in nz_train:
        
        if count%100000 == 0:
            print(count)
            
        difference = train[d,n] - mat_pred[d,n]
        
        # Updating the W
        
        gradient1 = -1* (difference) * user_features[n,:]
        item_features[d,:] = item_features[d,:] - gamma * gradient1
        

        # Updating the Z
        
        gradient2 = -1* (difference) * item_features[d,:]
        user_features[n,:] = user_features[n,:] - gamma * gradient2
        
        count += 1
            
    mat_pred = np.dot(item_features,user_features.T)
    print('beginning step 2')
    
    #Calculating training rmse
    for i in range(len(nz_train)):
        real_train_label[i] = train[nz_train[i][0],nz_train[i][1]]
        prediction_train[i] = mat_pred[nz_train[i][0],nz_train[i][1]]
        
    
    
    rmse_train[it] = calculate_mse(real_train_label, prediction_train) 
    
    rmse = rmse_train[it]
    
    print("iter: {}, RMSE on training set: {}.".format(it, rmse))
    end = datetime.datetime.now()
    execution_time = (end - begin).total_seconds()
    print(execution_time)
# Out:
# Iteration sankhya 0 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 0, RMSE on training set: 5.165188967688704.
# 33.927478
# Iteration sankhya 1 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 1, RMSE on training set: 3.8883215787866923.
# 32.364387
# Iteration sankhya 2 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 2, RMSE on training set: 3.1857147215299357.
# 32.141906
# Iteration sankhya 3 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 3, RMSE on training set: 2.7356951093525677.
# 31.491069
# Iteration sankhya 4 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 4, RMSE on training set: 2.4238790530092387.
# 31.700477
# Iteration sankhya 5 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 5, RMSE on training set: 2.197067906854837.
# 40.888316
# Iteration sankhya 6 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 6, RMSE on training set: 2.0264309594356775.
# 38.886175
# Iteration sankhya 7 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 7, RMSE on training set: 1.8947614902171268.
# 33.730964
# Iteration sankhya 8 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 8, RMSE on training set: 1.791093989204578.
# 37.341243
# Iteration sankhya 9 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 9, RMSE on training set: 1.7080983182456784.
# 33.264282
# Iteration sankhya 10 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 10, RMSE on training set: 1.6406937928620584.
# 45.030681
# Iteration sankhya 11 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 11, RMSE on training set: 1.5852580675823453.
# 39.411792
# Iteration sankhya 12 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 12, RMSE on training set: 1.539148573391402.
# 35.608137
# Iteration sankhya 13 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 13, RMSE on training set: 1.500400507990905.
# 38.205493
# Iteration sankhya 14 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 14, RMSE on training set: 1.4675299137792908.
# 40.287637
# Iteration sankhya 15 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 15, RMSE on training set: 1.439400715374588.
# 41.668718
# Iteration sankhya 16 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 16, RMSE on training set: 1.4151320223114734.
# 41.204761
# Iteration sankhya 17 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 17, RMSE on training set: 1.3940341974245423.
# 36.650956
# Iteration sankhya 18 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 18, RMSE on training set: 1.3755615496269415.
# 37.287994
# Iteration sankhya 19 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 19, RMSE on training set: 1.3592785119556774.
# 37.116423
# Iteration sankhya 20 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 20, RMSE on training set: 1.344834603717156.
# 33.197747
# Iteration sankhya 21 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 21, RMSE on training set: 1.3319456496394257.
# 43.708352
# Iteration sankhya 22 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 22, RMSE on training set: 1.32037948597651.
# 50.10253
# Iteration sankhya 23 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 23, RMSE on training set: 1.3099451033089653.
# 48.196725
# Iteration sankhya 24 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 24, RMSE on training set: 1.3004844500203345.
# 43.391404
# Iteration sankhya 25 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 25, RMSE on training set: 1.2918658639476814.
# 41.375007
# Iteration sankhya 26 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 26, RMSE on training set: 1.28397913981829.
# 54.924524
# Iteration sankhya 27 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 27, RMSE on training set: 1.2767314168669817.
# 39.104086
# Iteration sankhya 28 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 28, RMSE on training set: 1.270044133563329.
# 39.904841
# Iteration sankhya 29 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 29, RMSE on training set: 1.263850388299994.
# 37.960224
# Iteration sankhya 30 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 30, RMSE on training set: 1.2580930459222976.
# 41.61797
# Iteration sankhya 31 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 31, RMSE on training set: 1.2527231303797208.
# 42.528521
# Iteration sankhya 32 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 32, RMSE on training set: 1.2476983461983215.
# 37.652462
# Iteration sankhya 33 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 33, RMSE on training set: 1.2429820742911268.
# 39.377336
# Iteration sankhya 34 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 34, RMSE on training set: 1.2385425339683855.
# 38.305103
# Iteration sankhya 35 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 35, RMSE on training set: 1.2343520463888582.
# 42.732913
# Iteration sankhya 36 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 36, RMSE on training set: 1.230386312508477.
# 41.660873
# Iteration sankhya 37 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 37, RMSE on training set: 1.2266241202140693.
# 41.449542
# Iteration sankhya 38 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 38, RMSE on training set: 1.223046706535808.
# 39.964097
# Iteration sankhya 39 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 39, RMSE on training set: 1.2196375322822857.
# 43.110877
# Iteration sankhya 40 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 40, RMSE on training set: 1.2163819136606644.
# 39.37975
# Iteration sankhya 41 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 41, RMSE on training set: 1.213266766771181.
# 51.437566
# Iteration sankhya 42 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 42, RMSE on training set: 1.2102806010648495.
# 40.136114
# Iteration sankhya 43 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 43, RMSE on training set: 1.2074129568873884.
# 45.026957
# Iteration sankhya 44 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 44, RMSE on training set: 1.2046545687288186.
# 39.889503
# Iteration sankhya 45 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 45, RMSE on training set: 1.201997201304996.
# 42.580887
# Iteration sankhya 46 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 46, RMSE on training set: 1.199433304589189.
# 43.653474
# Iteration sankhya 47 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 47, RMSE on training set: 1.196956073845555.
# 39.596206
# Iteration sankhya 48 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 48, RMSE on training set: 1.1945594993581194.
# 50.057601
# Iteration sankhya 49 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 49, RMSE on training set: 1.1922380535210237.
# 41.493006

# %%
plt.plot(rmse_train)

# %%
real_train_label = np.zeros(len(nz_train))
prediction_train = np.zeros(len(nz_train))
rmse_train_new = np.zeros(num_epochs)

for it in range(50,150): 
    
    print('Iteration sankhya',it,'haazir hoooooo!!!')
    # shuffle the training rating indices
    np.random.shuffle(nz_train)

    # decrease step size
    # gamma /= 1.2
    count = 0
    mat_pred = np.dot(item_features,user_features.T)
    begin = datetime.datetime.now()
    print('beginning step 1')
    count = 0
    for d,n in nz_train:
        
        if count%100000 == 0:
            print(count)
            
        difference = train[d,n] - mat_pred[d,n]
        
        # Updating the W
        
        gradient1 = -1* (difference) * user_features[n,:]
        item_features[d,:] = item_features[d,:] - gamma * gradient1
        

        # Updating the Z
        
        gradient2 = -1* (difference) * item_features[d,:]
        user_features[n,:] = user_features[n,:] - gamma * gradient2
        
        count += 1
            
    mat_pred = np.dot(item_features,user_features.T)
    print('beginning step 2')
    
    #Calculating training rmse
    for i in range(len(nz_train)):
        real_train_label[i] = train[nz_train[i][0],nz_train[i][1]]
        prediction_train[i] = mat_pred[nz_train[i][0],nz_train[i][1]]
        
    
    
    rmse_train_new[it-50] = calculate_mse(real_train_label, prediction_train) 
    
    rmse = rmse_train_new[it-50]
    
    print("iter: {}, RMSE on training set: {}.".format(it, rmse))
    end = datetime.datetime.now()
    execution_time = (end - begin).total_seconds()
    print(execution_time)
# Out:
# Iteration sankhya 50 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 50, RMSE on training set: 1.187800924086863.
# 48.863731
# Iteration sankhya 51 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 51, RMSE on training set: 1.1856765252899548.
# 42.841945
# Iteration sankhya 52 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 52, RMSE on training set: 1.1836097499983744.
# 40.942748
# Iteration sankhya 53 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 53, RMSE on training set: 1.181597207789748.
# 46.371552
# Iteration sankhya 54 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 54, RMSE on training set: 1.179635642254871.
# 46.991717
# Iteration sankhya 55 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 55, RMSE on training set: 1.1777221958851172.
# 61.331028
# Iteration sankhya 56 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 56, RMSE on training set: 1.1758542186752634.
# 43.353495
# Iteration sankhya 57 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 57, RMSE on training set: 1.174029259119934.
# 38.843182
# Iteration sankhya 58 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 58, RMSE on training set: 1.1722450537565443.
# 41.45191
# Iteration sankhya 59 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 59, RMSE on training set: 1.170499531735474.
# 41.046518
# Iteration sankhya 60 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 60, RMSE on training set: 1.1687907740457908.
# 38.418034
# Iteration sankhya 61 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 61, RMSE on training set: 1.1671170140618217.
# 40.093222
# Iteration sankhya 62 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 62, RMSE on training set: 1.1654765521608133.
# 37.531148
# Iteration sankhya 63 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 63, RMSE on training set: 1.1638678873570254.
# 38.889815
# Iteration sankhya 64 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 64, RMSE on training set: 1.1622895711539327.
# 42.363779
# Iteration sankhya 65 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 65, RMSE on training set: 1.1607403023435936.
# 38.86609
# Iteration sankhya 66 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 66, RMSE on training set: 1.1592188408873372.
# 38.565616
# Iteration sankhya 67 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 67, RMSE on training set: 1.157724045367033.
# 41.897353
# Iteration sankhya 68 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 68, RMSE on training set: 1.1562548427675137.
# 52.946645
# Iteration sankhya 69 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 69, RMSE on training set: 1.154810228972538.
# 46.206434
# Iteration sankhya 70 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 70, RMSE on training set: 1.153389229197938.
# 41.534879
# Iteration sankhya 71 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 71, RMSE on training set: 1.1519909749869974.
# 41.12968
# Iteration sankhya 72 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 72, RMSE on training set: 1.1506146468442497.
# 40.895747
# Iteration sankhya 73 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 73, RMSE on training set: 1.1492594585971148.
# 41.490947
# Iteration sankhya 74 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 74, RMSE on training set: 1.147924690488286.
# 53.897862
# Iteration sankhya 75 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 75, RMSE on training set: 1.1466096211571335.
# 40.256394
# Iteration sankhya 76 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 76, RMSE on training set: 1.1453136381285534.
# 41.524195
# Iteration sankhya 77 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 77, RMSE on training set: 1.1440361172303077.
# 41.734537
# Iteration sankhya 78 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 78, RMSE on training set: 1.1427764863957293.
# 42.494579
# Iteration sankhya 79 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 79, RMSE on training set: 1.1415341803626495.
# 61.428122
# Iteration sankhya 80 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 80, RMSE on training set: 1.1403086990491034.
# 61.313031
# Iteration sankhya 81 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 81, RMSE on training set: 1.1390995230719954.
# 46.984915
# Iteration sankhya 82 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 82, RMSE on training set: 1.1379062221570697.
# 40.978968
# Iteration sankhya 83 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 83, RMSE on training set: 1.1367283140195514.
# 38.719183
# Iteration sankhya 84 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 84, RMSE on training set: 1.1355654282405028.
# 36.757293
# Iteration sankhya 85 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 85, RMSE on training set: 1.1344170829066829.
# 31.625917
# Iteration sankhya 86 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 86, RMSE on training set: 1.1332829524269736.
# 31.605132
# Iteration sankhya 87 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 87, RMSE on training set: 1.132162683730235.
# 31.0692
# Iteration sankhya 88 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 88, RMSE on training set: 1.1310559116196854.
# 31.312836
# Iteration sankhya 89 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 89, RMSE on training set: 1.1299622956007953.
# 30.175548
# Iteration sankhya 90 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 90, RMSE on training set: 1.1288815392536053.
# 31.455968
# Iteration sankhya 91 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 91, RMSE on training set: 1.1278133330678612.
# 30.715235
# Iteration sankhya 92 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 92, RMSE on training set: 1.126757388430302.
# 31.66688
# Iteration sankhya 93 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 93, RMSE on training set: 1.125713433181658.
# 30.142008
# Iteration sankhya 94 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 94, RMSE on training set: 1.1246812247621734.
# 30.35447
# Iteration sankhya 95 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 95, RMSE on training set: 1.1236604466120372.
# 30.702011
# Iteration sankhya 96 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 96, RMSE on training set: 1.122650882291453.
# 31.471658
# Iteration sankhya 97 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 97, RMSE on training set: 1.1216523272705616.
# 30.310104
# Iteration sankhya 98 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 98, RMSE on training set: 1.1206645412147787.
# 30.808569
# Iteration sankhya 99 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 99, RMSE on training set: 1.1196872537278857.
# 30.441604
# Iteration sankhya 100 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-71-3ce0d635d5f1> in <module>()
#      46
#      47
# ---> 48     rmse_train_new[it-50] = calculate_mse(real_train_label, prediction_train)
#      49
#      50     rmse = rmse_train_new[it-50]
#
# IndexError: index 50 is out of bounds for axis 0 with size 50

# %%
plt.plot(rmse_train_new)

# %%
it
# Out:
# 100

# %%
real_train_label = np.zeros(len(nz_train))
prediction_train = np.zeros(len(nz_train))
rmse_train_new1 = np.zeros(num_epochs)

for it in range(100,150): 
    
    print('Iteration sankhya',it,'haazir hoooooo!!!')
    # shuffle the training rating indices
    np.random.shuffle(nz_train)

    # decrease step size
    # gamma /= 1.2
    count = 0
    mat_pred = np.dot(item_features,user_features.T)
    begin = datetime.datetime.now()
    print('beginning step 1')
    count = 0
    for d,n in nz_train:
        
        if count%100000 == 0:
            print(count)
            
        difference = train[d,n] - mat_pred[d,n]
        
        # Updating the W
        
        gradient1 = -1* (difference) * user_features[n,:]
        item_features[d,:] = item_features[d,:] - gamma * gradient1
        

        # Updating the Z
        
        gradient2 = -1* (difference) * item_features[d,:]
        user_features[n,:] = user_features[n,:] - gamma * gradient2
        
        count += 1
            
    mat_pred = np.dot(item_features,user_features.T)
    print('beginning step 2')
    
    #Calculating training rmse
    for i in range(len(nz_train)):
        real_train_label[i] = train[nz_train[i][0],nz_train[i][1]]
        prediction_train[i] = mat_pred[nz_train[i][0],nz_train[i][1]]
        
    
    
    rmse_train_new1[it-100] = calculate_mse(real_train_label, prediction_train) 
    
    rmse = rmse_train_new1[it-100]
    
    print("iter: {}, RMSE on training set: {}.".format(it, rmse))
    end = datetime.datetime.now()
    execution_time = (end - begin).total_seconds()
    print(execution_time)
# Out:
# Iteration sankhya 100 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 100, RMSE on training set: 1.1168166569583688.
# 44.214046
# Iteration sankhya 101 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 101, RMSE on training set: 1.1158795481829085.
# 54.45631
# Iteration sankhya 102 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 102, RMSE on training set: 1.1149519850141547.
# 38.124038
# Iteration sankhya 103 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 103, RMSE on training set: 1.1140338378391683.
# 47.571343
# Iteration sankhya 104 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 104, RMSE on training set: 1.1131249348199337.
# 42.022163
# Iteration sankhya 105 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 105, RMSE on training set: 1.1122250738025123.
# 52.908704
# Iteration sankhya 106 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 106, RMSE on training set: 1.1113341185825198.
# 40.309666
# Iteration sankhya 107 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 107, RMSE on training set: 1.1104519054404072.
# 33.554153
# Iteration sankhya 108 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 108, RMSE on training set: 1.1095782991830145.
# 32.820969
# Iteration sankhya 109 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 109, RMSE on training set: 1.1087131438599909.
# 30.826103
# Iteration sankhya 110 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 110, RMSE on training set: 1.1078563201479903.
# 33.540814
# Iteration sankhya 111 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 111, RMSE on training set: 1.1070076850784862.
# 30.670403
# Iteration sankhya 112 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 112, RMSE on training set: 1.1061671071359978.
# 33.872352
# Iteration sankhya 113 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 113, RMSE on training set: 1.1053344498914417.
# 34.471536
# Iteration sankhya 114 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 114, RMSE on training set: 1.1045095944611996.
# 29.753403
# Iteration sankhya 115 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 115, RMSE on training set: 1.103692429363539.
# 35.927263
# Iteration sankhya 116 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 116, RMSE on training set: 1.1028828163399889.
# 29.936503
# Iteration sankhya 117 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 117, RMSE on training set: 1.1020806497058762.
# 32.753794
# Iteration sankhya 118 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 118, RMSE on training set: 1.1012858464186193.
# 36.169233
# Iteration sankhya 119 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 119, RMSE on training set: 1.1004982508489383.
# 31.027693
# Iteration sankhya 120 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 120, RMSE on training set: 1.099717777714206.
# 33.563473
# Iteration sankhya 121 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 121, RMSE on training set: 1.0989443181825689.
# 29.872754
# Iteration sankhya 122 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 122, RMSE on training set: 1.0981777701304467.
# 34.085845
# Iteration sankhya 123 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 123, RMSE on training set: 1.0974180574078602.
# 31.714629
# Iteration sankhya 124 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 124, RMSE on training set: 1.0966650718121451.
# 29.627505
# Iteration sankhya 125 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 125, RMSE on training set: 1.0959187057202515.
# 29.982899
# Iteration sankhya 126 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 126, RMSE on training set: 1.0951788952500094.
# 29.764312
# Iteration sankhya 127 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 127, RMSE on training set: 1.094445552088402.
# 31.733038
# Iteration sankhya 128 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 128, RMSE on training set: 1.0937185798736564.
# 31.329242
# Iteration sankhya 129 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 129, RMSE on training set: 1.092997888499791.
# 30.23508
# Iteration sankhya 130 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 130, RMSE on training set: 1.0922833837705808.
# 33.195253
# Iteration sankhya 131 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 131, RMSE on training set: 1.0915750158953677.
# 32.83514
# Iteration sankhya 132 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 132, RMSE on training set: 1.0908726907550697.
# 32.824872
# Iteration sankhya 133 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 133, RMSE on training set: 1.0901763299953116.
# 30.021824
# Iteration sankhya 134 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 134, RMSE on training set: 1.08948584561987.
# 29.999071
# Iteration sankhya 135 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 135, RMSE on training set: 1.0888011777007338.
# 29.845711
# Iteration sankhya 136 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 136, RMSE on training set: 1.0881222521851552.
# 33.081724
# Iteration sankhya 137 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 137, RMSE on training set: 1.087448999105152.
# 33.620521
# Iteration sankhya 138 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 138, RMSE on training set: 1.0867813175613654.
# 40.079804
# Iteration sankhya 139 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 139, RMSE on training set: 1.0861191580448883.
# 45.778569
# Iteration sankhya 140 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 140, RMSE on training set: 1.0854624711293566.
# 34.342673
# Iteration sankhya 141 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 141, RMSE on training set: 1.0848111803341602.
# 43.629062
# Iteration sankhya 142 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 142, RMSE on training set: 1.0841652162252786.
# 33.14562
# Iteration sankhya 143 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 143, RMSE on training set: 1.0835245213262352.
# 35.912011
# Iteration sankhya 144 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 144, RMSE on training set: 1.0828890275310676.
# 36.667005
# Iteration sankhya 145 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 145, RMSE on training set: 1.082258684408654.
# 34.861469
# Iteration sankhya 146 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 146, RMSE on training set: 1.0816333850404967.
# 31.591682
# Iteration sankhya 147 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 147, RMSE on training set: 1.0810131226415989.
# 35.922193
# Iteration sankhya 148 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 148, RMSE on training set: 1.0803978127557288.
# 33.846185
# Iteration sankhya 149 haazir hoooooo!!!
# beginning step 1
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# beginning step 2
# iter: 149, RMSE on training set: 1.0797874112989765.
# 35.165179

# %%
plt.plot(rmse_train_new1)

# %%
plt.plot(np.concatenate((rmse_train,rmse_train_new, rmse_train_new1),axis=0))
